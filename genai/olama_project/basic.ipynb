# %%
#//using olama model without lanchan api


from langchain_ollama import OllamaLLM

llm=OllamaLLM(model="llama2")

#import olama model

#invoke function- usede to ask ques

response=llm.invoke("explain langchain in 2 lines")


#for frontend- take input from user and then through request pass this
#input to backend and print response on fronetend

response
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[1], line 12
#       6 llm=OllamaLLM(model="llama2")
#       8 #import olama model
#       9
#      10 #invoke function- usede to ask ques
# ---> 12 response=llm.invoke("explain langchain in 2 lines")
#      15 #for frontend- take input from user and then through request pass this
#      16 #input to backend and print response on fronetend
#      18 response
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_core\language_models\llms.py:392, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     381 @override
#     382 def invoke(
#     383     self,
#    (...)    388     **kwargs: Any,
#     389 ) -> str:
#     390     config = ensure_config(config)
#     391     return (
# --> 392         self.generate_prompt(
#     393             [self._convert_input(input)],
# ...
