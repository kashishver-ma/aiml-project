# %%
import os



os.listdir(os.getcwd()) #current work dir
os.chdir('D:\\aimlworkshop\\dl\\CNN')
print(os.getcwd())
os.chdir('D:\\aimlworkshop\\os')
# os.mkdir("test")
# os.rmdir("test")
os.path.exists("basic.ipynb")
os.path.isdir("basic.ipynb")
os.path.isfile("basic.ipynb")
# Out:
# D:\aimlworkshop\dl\CNN
# True
