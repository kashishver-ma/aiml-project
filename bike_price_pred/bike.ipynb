# %%
import pandas as pd

# %%
df = pd.read_csv('Used_Bikes.csv')
df.head()

# %%
df.tail()

# %%
df.info()

# %%
df.shape

# %%
df.duplicated()

# %%
df.duplicated().sum()

# %%
df.drop_duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()

# %%
#df.dropna(inplace=True) if there is a null value then we use this dropna() function to remove null values

# %%
df.columns

# %%
df

# %%
df['brand'].value_counts()

# %%
df['brand'].unique()

# %%
df['brand'].nunique()

# %%
df['owner'].unique()

# %%
df['owner'].nunique()

# %%
df['owner'].value_counts()

# %%
df.describe()

# %%
df.describe().mean()

# %%
Bajaj_brand_df =df[df['brand']=='Bajaj']

# %%
first_Bajaj_df = Bajaj_brand_df[Bajaj_brand_df['owner']=="First Owner"]

# %%
first_Bajaj_df

# %%
first_Bajaj_df[first_Bajaj_df['kms_driven']<=50000]

# %%
#droping unused columns
# 
df.drop(['bike_name','city'],inplace=True, axis = 1)

# %%
df

# %%
df['owner'].unique()

# %%
dct = {
  'First Owner':1, 'Second Owner':2, 'Third Owner':3,
       'Fourth Owner Or More':4 
}

# %%
df['owner']=df['owner'].map(dct)

# %%
df

# %%
df['owner'].unique()

# %%
df['brand'].unique()

# %%
brand_dct = {
    'TVS':1, 'Royal Enfield':2, 'Triumph':3, 'Yamaha':4, 'Honda':5, 'Hero':6,
       'Bajaj':7, 'Suzuki':8, 'Benelli':9, 'KTM':10, 'Mahindra':11, 'Kawasaki':12,
       'Ducati':13, 'Hyosung':14, 'Harley-Davidson':15, 'Jawa':16, 'BMW':17, 'Indian':18,
       'Rajdoot':19, 'LML':20, 'Yezdi':21, 'MV':22, 'Ideal':23
}

# %%
df['brand']=df['brand'].map(brand_dct)

# %%
df

# %%
x = df.drop('price', axis=1)
y = df[['price']]

# %%
x

# %%
y
#print all columns of x
x.columns

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y ,random_state=42, test_size=0.2)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)

# %%
lr.score(x_train, y_train)

# %%
lr.score(x_test, y_test)

# %%
lr.predict(x_test)

# %%
# Predicted line
# y_pred = lr.predict()

# %%
#how to save this model and how to use this model
#joblib already install in system

import joblib
#object nm , "model.lb" -------> saved model
model = joblib.dump(lr, "model.lb")

# %%
#using model direclty

model = joblib.load("model.lb")
model.predict(x_test)

# %%
# loss=actual-predeiction
# 4 types - msc,mae,rms,rmse root mean mean square error, 

#suport vector regression

from sklearn.svm import SVR

sv=SVR()

sv.fit(x_test,y_test)
pred= sv.predict(x_test)
pred

# %%
sv.score(x_train,y_train)
sv.score(x_test,y_test)

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
print(rf.score(x_train,y_train))
print(rf.score(x_test,y_test))
rfpredict=rf.predict(x_test)
joblib.dump(rf,"rfmodel.lb")
# --- IGNORE ---

# %%
# !pip install xgboost
# import xgboost as xgb
# xg = xgb.XGBRegressor()
# xg.fit(x_train, y_train)
# xg.score(x_train, y_train)
# xg.score(x_test, y_test)
# xg.predict(x_test)
# # --- IGNORE --------> new file
